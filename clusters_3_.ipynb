# %% [markdown]
# # Importar las librerias y los algoritmos necesarios para la tarea

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.datasets import make_blobs

# %% [markdown]
# # Generar datos aleatorios usando make_blobs

# %%
np.random.seed(42)
n_puntos = 1000
centros = np.array([[0, 0], [1, 1], [2, 2]])
datos, _ = make_blobs(n_samples=n_puntos, centers=centros, cluster_std=0.2,random_state=42)

# %% [markdown]
# # Aplicar los modelos

# %% [markdown]
# ## K-Means

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(datos)
etiquetas_kmeans = kmeans.labels_
# Out:
# -77.98061885148955

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN(eps=0.34)
dbscan.fit(datos)
etiquetas_dbscan = dbscan.labels_

# %% [markdown]
# # Evaluación de los modelos

# %%
from sklearn import metrics
kmeans_metric = metrics.silhouette_score(datos,etiquetas_kmeans)
dbscan_metric = metrics.silhouette_score(datos,etiquetas_dbscan)
print("KMeans silhouette score = ", kmeans_metric)
print("DBSCAN silhouette score = ", dbscan_metric)
# Out:
# KMeans silhouette score =  0.7433496845205193
# DBSCAN silhouette score =  0.7433496845205193

# %% [markdown]
# # Visualizar los clusters

# %%
plt.figure(figsize=(5, 5))

# KMeans
plt.scatter(datos[:, 0], datos[:, 1], c=etiquetas_kmeans, cmap='viridis')
plt.title("KMeans")
plt.xlabel("Coordenada X")
plt.ylabel("Coordenada Y")

plt.show()

# %%
# DBSCAN

plt.scatter(datos[:, 0], datos[:, 1], c=etiquetas_dbscan, cmap='viridis')
plt.title("DBSCAN")
plt.xlabel("Coordenada X")
plt.ylabel("Coordenada Y")

#plt.tight_layout()
plt.show()

# %% [markdown]
# Explicación:
#
# 1. Generación de datos con make_blobs:
#    - Se utiliza la función make_blobs de sklearn.datasets para generar datos aleatorios alrededor de los puntos centrales definidos en centros.
#    - Se especifica el número de puntos (n_puntos), los centros de los clusters (centros), la desviación estándar de los clusters (cluster_std) y una semilla aleatoria (random_state) para la reproducibilidad.
#    - La función make_blobs devuelve un array con los datos y un array con las etiquetas de los clusters (que no se utilizan en este caso).
#
# 2. Aplicación de KMeans y DBSCAN:
#    1. KMeans
#       - Se crea un objeto KMeans con 3 clusters y una semilla aleatoria para la inicialización.
#       - Se ajusta el modelo a los datos usando kmeans.fit(datos).
#       - Se obtiene un array con las etiquetas de los clusters predichos para cada punto usando kmeans.labels_.
#    2. DBSCAN
#       - Se crea un objeto DBSCAN con un valor de eps (distancia máxima para considerar puntos como vecinos) de 0.34 y min_sample(número mínimo de puntos para formar un cluster) de 10.
#       - Se ajusta el modelo a los datos usando dbscan.fit(datos).
#       - Se obtiene un array con las etiquetas de los clusters predichos para cada punto usando dbscan.labels_.
